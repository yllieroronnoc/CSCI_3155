// %% [markdown]
// <pre>
// let x = 10 in x + 20
//
// eval(expr, env(mapping from string to values))
//
// we needed an environment for scope,
//
// eval(expr, env) -> value
//
//
// like eval, (evaluation function) we would like to define a type of function
// which is a type computing function
//
// typeof(let x = 20 in x + y, [ y -> num ] )    this is an ill typed expression under a empty environment
//
// typeof: expr -> typeenv -> type
// takes ecpresion under type environment and returns a type
//
// for welltyped y should be a num type
//
//
//
//
//                 -
// ----------------------------------
//         eval(const(n), o) = n
//
// evaluation rule
//
// type rule
//
//                 -
// -----------------------------------
//         typeof(const(n), a) = num
//
//         type(e1, a) = bool, typeof(e2,a) = t', typeof(e3,a) also t,
// ---------------------------------------------------
//             typeof(ifthenelse(e1,e2,e3),a) = t
//
// only well typed if e1 = bool and e2 and e3 are the same
// if t != t' error, if typeof(e1) != bool error
//
//         type(e1,a) = typeof(e2,a) = num
// --------------------------------------------------
//         typeof(Plus(e1,e2), a) = num
//
//
// and
//
//         type(e1,a) = type(e2,a) = bool
// ------------------------------------------------------
//                typeof(and(e1,e2),a) = bool
//
//
// geq
//
//             type(e1,a) = type(e2,a) = num
// ------------------------------------------------------
//                typeof(geq(e1,e2),a) = bool
//
//
//             typeof(e1,a) = t1, a' = a[x->t1], type(e2,a') = t2
// ------------------------------------------------------
//                typeof(let(x,t1,e1,e2),a) = t2
//
//
//
//         typeof(e1,a) = t1->t2, typeof(e2,a) = t1
// ------------------------------------------------------
//                typeof(funcall(e1,e2),a) = t2
//
//
//           a' = a[x->t1] , typeof(e,a') = t2
// ------------------------------------------------------
//                typeof(fundef(x,t1,e),a) = t1->t2
//
//           typeof(e1,a[f->t11->t22,x:t11]) =  t12
// ------------------------------------------------------
//                typeof(letrec(f,t1,x,t2,e1,e2),a) = t1->t2
// </pre>
