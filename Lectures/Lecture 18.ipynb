// %% [markdown]
// # Lecture 18
// Project 2
// title: Lettuce with figs
// doing: write domain specific language for creating figures
//
// <pre>
// added case class Reference(j: Int) extends Value
//     helpful functions, unboxing functions
//     just helping convert values to number, boolean or closure
// implementation
//
//     type Store = ArrayBuffer[Value]
// using an array buffer, mutable data structure
// array buffers can grow and shrink where array just has a set size
//
// functions for the store
//
// def createnewcell(s: Store, v: Value): (Store, Int) = {
//     val j = s.length
//     val nStore = s:+(v)
//     (nStore, j)
// }
//
// def lookupCellValue(s: Store, j: Int): Value = {
//     if(j lt s.length){
//         s(j)
//      } else {
//          throw new illegal
//      }
// }
//
// def assignToCell(s:Store, j: Int, v:Value): Store = {
//     if(j lt s.length){
//         s(j) = v
//         } else {
//         throw new illegal
//         }
// }
//
//
// ident(x) => {
//     val v = env(x)
//     v match{
//         case reference(j) => {
//             val v1 = lookup
//             (v1, store)
//         }
//         case _=> v,store
//
// Garbage Collection
//
// Let var x = ( let var z = 10
//                 in
//                 z )
//     in
//         x
//
//
//
// </pre>
